# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

from collections import Counter

data = pd.read_csv("spotify-2023.csv")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data['streams'] = data['streams'].str.replace(',', '', regex=True)
data['streams (int)'] = pd.to_numeric(data['streams'], errors='coerce')

def myfilter(x):
    return list(map(lambda x: x.strip(), str(x).replace("Tyler, The Creator","Tyler - The Creator").split(',')))
    
artists = data['artist(s)_name'].apply(myfilter)


#artists = artists[artists.apply(lambda x : len(x) == 1)]

fart = set()
for i in artists:
    for j in i:
        if j.strip() != '':
            fart.add(j.strip())
print(len(fart))
fart
# Out:
# 697
# {'(G)I-DLE',
#  '070 Shake',
#  '21 Savage',
#  '24kgoldn',
#  '2Pac',
#  '347aidan',
#  '4*TOWN (From Disney and Pixar���s Turning Red)',
#  '50 Cent',
#  'A Boogie Wit da Hoodie',
#  'A$AP Rocky',
#  'ACRAZE',
#  'AP Dhillon',
#  'ARIZONATEARS',
#  "AX'EL",
#  'Abhijay Sharma',
#  'Abhir Hathi',
#  'Adassa',
#  'Adele',
#  'Aerosmith',
#  'AgroPlay',
#  'Agust D',
#  'Aitana',
#  'Aitch',
#  'Ak4:20',
#  'Alec Benjamin',
#  'Alejo',
#  'Alesso',
#  'Ali Sethi',
#  'Alicia Keys',
#  'Altamash Faridi',
#  'Alvaro Diaz',
#  'Amaarae',
#  'Amanda Reifer',
#  'Amitabh Bhattacharya',
#  'Amitabha Bhattacharya',
#  'Ana Castela',
#  'Anderson .Paak',
#  'Andy Williams',
#  'Angela Aguilar',
#  'Anggi Marito',
#  'Anitta',
#  'Anne-Marie',
#  'AnnenMayKantereit',
#  'Anuel Aa',
#  'Aqua',
#  'Arcane',
#  'Arcangel',
#  'Arctic Monkeys',
#  'Ariana Grande',
#  'Arijit Singh',
#  'Armani White',
#  'Ava',
#  'Aventura',
#  'Avicii',
#  'Ayparia',
#  'B. Swanson Quartet',
#  'BIGBANG',
#  'BL',
#  'BLACKPINK',
#  'BLESSD',
#  'BTS',
#  'BYOR',
#  'Baby Keem',
#  'Baby Rasta',
#  'Baby Tate',
#  'Bad B',
#  'Bad Bunny',
#  'Band Aid',
#  'Beach House',
#  'Beach Weather',
#  'Beam',
#  'Bebe Rexha',
#  'Becky G',
#  'Becky Hill',
#  'Bellakath',
#  'Benny Blanco',
#  'Benson Boone',
#  'Beth Gibbons',
#  'Beyonc�',
#  'Be��',
#  'Bianca',
#  'Big One',
#  'Billie Eilish',
#  'Bing Crosby',
#  'Bizarrap',
#  'Black Eyed Peas',
#  'Blackbear',
#  'Blake Shelton',
#  'Blanco',
#  'Blxst',
#  'Bobby Helms',
#  'Bomba Est��reo',
#  'BoyWithUke',
#  'Bradley Cooper',
#  'Brenda Lee',
#  'Britney Spears',
#  'Brray',
#  'Bruno Mars',
#  'Burl Ives',
#  'Burna Boy',
#  'Buscabulla',
#  'Bvga Beatz',
#  'B�',
#  'B��jo',
#  'C. Tangana',
#  'Calum Scott',
#  'Calvin Harris',
#  'Camila Cabello',
#  'Caralisa Monteiro',
#  'Cardi B',
#  'Carin Leon',
#  'Carolina Gaitan',
#  'Cartel De Santa',
#  'Central Cee',
#  'Chanel',
#  'Charli XCX',
#  'Charlie Puth',
#  'Chase Atlantic',
#  'Chefin',
#  'Chencho Corleone',
#  'Cherish',
#  'Childish Gambino',
#  'Chino Pacas',
#  'Chris Brown',
#  'Chris Jedi',
#  'Chris Molitor',
#  'Chris Rea',
#  'Christian Nodal',
#  'Chuck Berry',
#  'Cigarettes After Sex',
#  'Ckay',
#  'Coi Leray',
#  'Colde',
#  'Coldplay',
#  'Colin Hay',
#  'Conan Gray',
#  'Coolio',
#  'Creedence Clearwater Revival',
#  'Cris Mj',
#  'Cruz Cafun��',
#  'DJ 900',
#  'DJ Biel do Furduncinho',
#  'DJ Escobar',
#  'DJ Khaled',
#  'DJ Luian',
#  'DJ Matt D',
#  'DJ R',
#  'DJ Win',
#  'DaBaby',
#  'Daddy Yankee',
#  'Daft Punk',
#  'Dalex',
#  'Daniel Caesar',
#  'Danny Ocean',
#  'Darlene Love',
#  'Dave',
#  'Davi K',
#  'David Guetta',
#  'David Kushner',
#  'Dazy',
#  'De La Ghetto',
#  'Dean Lewis',
#  'Dean Martin',
#  'Demi Lovato',
#  'Diane Guerrero',
#  'Dido',
#  'Dimelo Flow',
#  'Dina Rae',
#  'Dj Chris No Beat',
#  'Dj Gabriel do Borel',
#  'Dj LK da Esc��cia',
#  'Dj Yo!',
#  'Doechii',
#  'Doja Cat',
#  'Don Omar',
#  'Don Toliver',
#  'Dopamine',
#  'Dove Cameron',
#  'Do��u',
#  'Dr. Dre',
#  'Drake',
#  'Dua Lipa',
#  'Duki',
#  'Duncan Laurence',
#  'ENHYPEN',
#  'Ed Sheeran',
#  'Eden Mu��',
#  'Edison Lighthouse',
#  'El Chachito',
#  'Eladio Carrion',
#  'Eliza Rose',
#  'Ella Henderson',
#  'Elley Duh�',
#  'Ellie Goulding',
#  'Elton John',
#  'Em Beihold',
#  'Emilia',
#  'Eminem',
#  'Emmy Meli',
#  'Encanto - Cast',
#  'Eric Church',
#  'Eslabon Armado',
#  'FIFA Sound',
#  'FMK',
#  'Farruko',
#  'Feid',
#  'Fifty Fifty',
#  "Finneas O'Connell",
#  'Fireboy DML',
#  'Fivio Foreign',
#  'Flowdan',
#  'Foudeqush',
#  'Fran C',
#  'Frank Ocean',
#  'Frank Sinatra',
#  'Fred again..',
#  'Freddie Dredd',
#  'Fuerza Regida',
#  'Fujii Kaze',
#  'Future',
#  'GODZZ__-',
#  'Gabito Ballesteros',
#  'Gabry Ponte',
#  'Gayle',
#  'George Henrique &',
#  'Gesaffelstein',
#  'Ghost',
#  'Ghostface Killah',
#  'Giant Rooks',
#  'Giveon',
#  'Glass Animals',
#  'Gorillaz',
#  'Gotye',
#  'Grayson Vill',
#  'Grupo Frontera',
#  'Grupo Marca Registrada',
#  'Gunna',
#  "Guns N' Roses",
#  'Gurinder Gill',
#  'Gustah',
#  'Gustavo Mioto',
#  'Gwen Stefani',
#  'HA SUNG WOON',
#  'Hallie Coggins',
#  'Halsey',
#  'Harry Styles',
#  'Hotel Ugly',
#  'Hozier',
#  'Hugo & G',
#  'Huilen Toledo',
#  'INTERWORLD',
#  'IU',
#  'IVE',
#  'Iann Dior',
#  'Ice Spice',
#  'Imagine Dragons',
#  'Imanbek',
#  'Intense',
#  'Interplanetary Criminal',
#  'Israel & Rodolffo',
#  'J Balvin',
#  'J. Cole',
#  'JID',
#  'JISOO',
#  'JVKE',
#  'Jack Black',
#  'Jack Harlow',
#  'Jain',
#  'James Arthur',
#  'James Blake',
#  'James Hype',
#  'Jasiel Nu��ez',
#  'Jason Derulo',
#  'Jax Jones',
#  'Jay Rock',
#  'Jaymes Young',
#  'Jessi',
#  'Jessica Darrow',
#  'Jessie Reyez',
#  'Jhay Cortez',
#  'Jhayco',
#  'Jimin',
#  'Jin',
#  'Jnr Choi',
#  'Joel Corry',
#  'John Legend',
#  'John Lennon',
#  'John Scott Trotter & His Orchestra',
#  'Joji',
#  'Jonas Brothers',
#  'Jordan Fisher',
#  'Josh Levi',
#  'Jos�� Felic',
#  'Juan Cruz Toledo',
#  'Juice WRLD',
#  'Juicy J',
#  'Julieta Venegas',
#  'Jung Kook',
#  'Junior H',
#  'Juseph',
#  'Justin Bieber',
#  'Justin Quiles',
#  'Justin Timberlake',
#  'KALUSH',
#  'Kaifi Khalil',
#  'Kali Uchis',
#  'Kaliii',
#  'Kanii',
#  'Kanye West',
#  'Kar',
#  'Karol G',
#  'Kate Bush',
#  'Katy Perry',
#  'KayBlack',
#  'Ke personajes',
#  'Keane',
#  'Keisya Levronka',
#  'Kelly Clarkson',
#  'Ken Darby Singers',
#  'Kendrick Lamar',
#  'Kenia OS',
#  'Kenshi Yonezu',
#  'Kevin Gates',
#  'Kevin Kaarl',
#  'Khalid',
#  'Kim Petras',
#  'Kimbra',
#  'King',
#  'Kodak Black',
#  'Kordhell',
#  'Kumaar',
#  'Kyla',
#  'L-Gante',
#  'L.V.',
#  'L7nnon',
#  'LE SSERAFIM',
#  'LF System',
#  'LUM!X',
#  'La Adictiva',
#  'La Joaqui',
#  'La Kelly',
#  'La Pantera',
#  'Labrinth',
#  'Lady Gaga',
#  'Lana Del Rey',
#  'Lasso',
#  'Latto',
#  'Lauren Spencer Smith',
#  'League of Legends',
#  'Leah Kate',
#  'Lenny Tav��rez',
#  'Leo Santana',
#  'Lewis Capaldi',
#  'LiL CaKe',
#  'Libianca',
#  'Lil Baby',
#  'Lil Durk',
#  'Lil Nas X',
#  'Lil Tjay',
#  'Lil Uzi Vert',
#  'Lil Wayne',
#  'Lil Yachty',
#  'Linkin Park',
#  'Lisa',
#  'Lit Killah',
#  'Lizzo',
#  'Lizzy McAlpine',
#  'Lord Huron',
#  'Loreen',
#  'Lost Frequencies',
#  'Love Funk',
#  'Luar La L',
#  'Lucenzo',
#  'Luciano',
#  'Ludwig Goransson',
#  'Luis R Conriquez',
#  'Luke Combs',
#  'Luude',
#  'Lu��sa Sonza',
#  'Lyanno',
#  'M',
#  'MC Caverinha',
#  'MC Frog',
#  'MC Kevin o Chris',
#  'MC MENOR HR',
#  'MC MENOR SG',
#  'MC Ryan SP',
#  'MC Tairon',
#  'MC Xenon',
#  'MNEK',
#  'Mabel Matiz',
#  'Mac DeMarco',
#  'Macklemore',
#  'Madonna',
#  'Mae Muller',
#  'Mae Stephens',
#  'Mahalini',
#  'Mahmood',
#  'Maiara &',
#  'Mainstreet',
#  'Maldy',
#  'Maluma',
#  'Mambo Kingz',
#  'Manuel Turizo',
#  'Mari Fernandez',
#  'Maria Becerra',
#  'Mariah Carey',
#  'Maroon 5',
#  'Marshmello',
#  'Mar��lia Mendo',
#  'Mar��lia Mendon��a',
#  'Masked Wolf',
#  'Matu�',
#  'Matu��',
#  'Mauro Castillo',
#  'Mc Livinho',
#  'Mc Paiva ZS',
#  'Mc Pedrinho',
#  'Mc Vitin Da Igrejinha',
#  'Megan Thee Stallion',
#  'Meghan Trainor',
#  'Melanie Martinez',
#  'Melody',
#  'Mert Demir',
#  'Metallica',
#  'Metro Boomin',
#  'Michael Bubl�',
#  'Miggy Dela Rosa',
#  'Migrantes',
#  'Miguel',
#  'Miley Cyrus',
#  'Milo j',
#  'Mitchell Ayres & His Orchestra',
#  'Moliy',
#  'Mora',
#  'Morgan Wallen',
#  'Mr.Kitty',
#  'Mufasa & Hypeman',
#  'Muni Long',
#  'Musical Youth',
#  'Myke Towers',
#  'M��ne',
#  'NAV',
#  'NEIKED',
#  'NF',
#  'NICKI NICOLE',
#  'NIKI',
#  'NLE Choppa',
#  'NMIXX',
#  'Nat King Cole',
#  'Natanael Cano',
#  'Nate Dogg',
#  'Nayeon',
#  'Nengo Flow',
#  'Neo B',
#  'Nessa Barrett',
#  'New West',
#  'NewJeans',
#  'Niall Horan',
#  'Nicki Minaj',
#  'Nickoog Clk',
#  'Nicky Jam',
#  'Nicky Youre',
#  'Nico Valdi',
#  'Nightcrawlers',
#  'Nile Rodgers',
#  'Nio Garcia',
#  'Nirvana',
#  'Offset',
#  'Olga Merediz',
#  'Oliver Tree',
#  'Olivia Rodrigo',
#  'Omar Apollo',
#  'One Direction',
#  'OneRepublic',
#  'Os Gemeos da Putaria',
#  'Oscar Maydon',
#  'Ovy On The Drums',
#  'Oxlade',
#  'Ozuna',
#  'P!nk',
#  'PR1ISVX',
#  'PSY',
#  'Pablito Pesadilla',
#  'Pailita',
#  'Paloma Faith',
#  'Paloma Mami',
#  'Panic! At The Disco',
#  'Paul McCartney',
#  'Paulo Londra',
#  'Pedro Sampaio',
#  'Peggy Gou',
#  'Perry Como',
#  'Peso P',
#  'Peso Pluma',
#  'Pharrell Williams',
#  'Phoebe Bridgers',
#  'PinkPantheress',
#  'Plan B',
#  'Playboi Carti',
#  'PnB Rock',
#  'Pnau',
#  'Polima WestCoast',
#  'Polo G',
#  'Post Malone',
#  'Prezioso',
#  'Pritam',
#  'Prod Malax',
#  'Project Pat',
#  'Queen',
#  'Quevedo',
#  'RAYE',
#  'RM',
#  'ROSAL�',
#  'Radiohead',
#  'Raim Laode',
#  'Rauw Alejandro',
#  'Ray Dalton',
#  'Rels B',
#  'Residente',
#  'Rex Orange County',
#  'Rhenzy Feliz',
#  'Riar Saab',
#  'Rich Music',
#  'Rich The Kid',
#  'Rihanna',
#  'Riton',
#  'Robi',
#  'Robin Schulz',
#  'Roddy Ricch',
#  'Roger',
#  'Roisee',
#  'Romeo Santos',
#  'Rosa Linn',
#  'Rosa Walton',
#  'Rusherking',
#  'Ruth B.',
#  'Rvssian',
#  'Ryan Castro',
#  'Ryan Lewis',
#  'R��',
#  'R��ma',
#  'SALES',
#  'SEVENTEEN',
#  'SZA',
#  'Sabrina Carpenter',
#  'Sachin-Jigar',
#  'Saiko',
#  'Sam Dew',
#  'Sam Ryder',
#  'Sam Smith',
#  'Sampha',
#  'Saweetie',
#  'Sch��rze',
#  'Seafret',
#  'Sean Paul',
#  'Sebastian Yatra',
#  'Sech',
#  'Selena G',
#  'Selena Gomez',
#  'Semicenk',
#  'Shadab Faridi',
#  'Shae Gill',
#  "Shakin' Stevens",
#  'Shakira',
#  'Shawn Mendes',
#  'Shekhar Ravjiani',
#  'Shilpa Rao',
#  'Shubh',
#  'SiM',
#  'Sia',
#  'Sidhu Moose Wala',
#  'Silk Sonic',
#  'Simone Mendes',
#  'Skrillex',
#  'Sky Rompiendo',
#  'Sleepy hallow',
#  'Snoop Dogg',
#  'Sofia Carson',
#  'Sog',
#  'Southstar',
#  'Standly',
#  'Stars Music Chile',
#  'Stephanie Beatriz',
#  'Stephen Sanchez',
#  'Steve Aoki',
#  'Steve Lacy',
#  'Stray Kids',
#  'Stromae',
#  'Styrx',
#  'Suga',
#  'Suki Waterhouse',
#  'Sukriti Kakar',
#  'Summer Walker',
#  'Supernova Ent',
#  'Surf Curse',
#  'Swae Lee',
#  'Swedish House Mafia',
#  'TAEYANG',
#  'THE ANXIETY',
#  'TOMORROW X TOGETHER',
#  'TV Girl',
#  'TWICE',
#  'Tainy',
#  'Taiu',
#  'Tanna Leone',
#  'Tate M',
#  'Tate McRae',
#  'Taylor Swift',
#  'Taylour Paige',
#  'Tchakabum',
#  'Tears For Fears',
#  'Tems',
#  'Tesla Jnr',
#  'The Chainsmokers',
#  'The Fontane Sisters',
#  'The Goo Goo Dolls',
#  'The Harlem Community Choir',
#  'The Kid Laroi',
#  'The Killers',
#  'The Mar��',
#  'The Neighbourhood',
#  'The Plastic Ono Band',
#  'The Police',
#  'The Rare Occasions',
#  'The Ronettes',
#  'The Walters',
#  'The Weeknd',
#  'Thezth',
#  'ThxSoMch',
#  'Tiago pzk',
#  'Tini',
#  'Ti��',
#  'Ti��sto',
#  'Toian',
#  'Tom Odell',
#  'Tones and I',
#  'Tony Dize',
#  'Topher Ngo',
#  'Tory Lanez',
#  'Travis Scott',
#  'Treasure',
#  'Treyce',
#  'Troye Sivan',
#  'Trueno',
#  'Tulus',
#  'Twisted',
#  'Tyga',
#  'Tyler - The Creator',
#  'Tyler Cole',
#  'Ugly Dray',
#  'V',
#  'Vance Joy',
#  'Varun Jain',
#  'Veigh',
#  'Victor Cibrian',
#  'Villano Antillano',
#  'Vishal Dadlani',
#  'Vishal-Shekhar',
#  'Vundabar',
#  'Wham!',
#  'Willow',
#  'Wisin & Yandel',
#  'Wiu',
#  'Wiz Khalifa',
#  'WizKid',
#  'XXXTENTACION',
#  'Xam��',
#  'YEAT',
#  'YOASOBI',
#  'Yahritza Y Su Esencia',
#  'Yandel',
#  'Yng Lvcas',
#  'Yoko Ono',
#  'Young Miko',
#  'Young Thug',
#  'Yung Gravy',
#  'Yung Lean',
#  'Yuridia',
#  'Zach Bryan',
#  'Zakaria',
#  'Zendaya',
#  'Zion & Lennox',
#  'Z�� Fe',
#  'Z�� Neto & Crist',
#  'a-ha',
#  'd4vd',
#  'dennis',
#  'girl in red',
#  'j-hope',
#  'mc jhenny',
#  'sped up 8282',
#  'sped up nightcore',
#  'teto',
#  'unxbected',
#  'utku INC',
#  'zzoilo'}

# %%
data.describe()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
#  15  key                   858 non-null    object
#  16  mode                  953 non-null    object
#  17  danceability_%        953 non-null    int64
#  18  valence_%             953 non-null    int64
#  19  energy_%              953 non-null    int64
#  20  acousticness_%        953 non-null    int64
#  21  instrumentalness_%    953 non-null    int64
#  22  liveness_%            953 non-null    int64
#  23  speechiness_%         953 non-null    int64
# dtypes: int64(17), object(7)
# memory usage: 178.8+ KB

# %%
# Step 1: Split artist names into individual entries
data['artist_list'] = data['artist(s)_name'].apply(myfilter)

# Step 2: Flatten the list of artists and count occurrences
all_artists = [artist.strip() for artists in data['artist_list'] for artist in artists]
artist_counts = Counter(all_artists)

# Step 3: Find the top 10 artists with the most songs
top_10_artists = artist_counts.most_common(10)

# Step 4: Convert to a DataFrame for display
top_10_df = pd.DataFrame(top_10_artists, columns=['Artist', 'Song_Count'])

print(top_10_df)
# Out:
#            Artist  Song_Count
# 0       Bad Bunny          40
# 1    Taylor Swift          38
# 2      The Weeknd          37
# 3             SZA          23
# 4  Kendrick Lamar          23
# 5            Feid          21
# 6           Drake          19
# 7    Harry Styles          17
# 8      Peso Pluma          16
# 9       21 Savage          14

# %%
target_artists = top_10_df["Artist"].values
artists = data["artist_list"][data["artist_list"].apply(lambda x: any([artist in target_artists for artist in x]))]

print(artists[artists.apply(lambda x: "Bad Bunny" in x)])

# artists = artists[artists.apply(lambda x : len(x) > 1)]

te = TransactionEncoder()
te_data = te.fit(artists).transform(artists)

encoded_data = pd.DataFrame(te_data, columns=te.columns_)
frequent_itemsets = apriori(encoded_data, min_support=0.001, use_colnames=True)

print(frequent_itemsets)
# Out:
# 4                              [Bad Bunny]
# 10             [Bad Bunny, Grupo Frontera]
# 27                      [Tainy, Bad Bunny]
# 87           [Chencho Corleone, Bad Bunny]
# 92             [Bad Bunny, Eladio Carrion]
# 192                            [Bad Bunny]
# 217                  [Arcangel, Bad Bunny]
# 239                            [Bad Bunny]
# 291                [Nengo Flow, Bad Bunny]
# 332                  [Gorillaz, Bad Bunny]
# 362                            [Bad Bunny]
# 368                  [J Balvin, Bad Bunny]
# 377                            [Bad Bunny]
# 422                            [Bad Bunny]
# 490               [Bad Bunny, Jhay Cortez]
# 494            [Bad Bunny, Rauw Alejandro]
# 528    [Julieta Venegas, Bad Bunny, Tainy]
# 547                  [Aventura, Bad Bunny]
# 555               [Bad Bunny, Jhay Cortez]
# 570                [Sech, Bad Bunny, Mora]
# 632      [J Balvin, Nio Garcia, Bad Bunny]
# 676                            [Bad Bunny]
# 696              [Daddy Yankee, Bad Bunny]
# 716                            [Bad Bunny]
# 732              [Daddy Yankee, Bad Bunny]
# 766                            [Bad Bunny]
# 767                            [Bad Bunny]
# 770                            [Bad Bunny]
# 773                            [Bad Bunny]
# 775                 [Tony Dize, Bad Bunny]
# 777                [Buscabulla, Bad Bunny]
# 778                            [Bad Bunny]
# 781                            [Bad Bunny]
# 782                 [Bad Bunny, The Mar��]
# 784                            [Bad Bunny]
# 786                            [Bad Bunny]
# 788                            [Bad Bunny]
# 789                            [Bad Bunny]
# 790                     [Bad Bunny, Tainy]
# 792                            [Bad Bunny]
# Name: artist_list, dtype: object
#       support                                           itemsets
# 0    0.059072                                        (21 Savage)
# 1    0.004219                                            (Alejo)
# 2    0.004219                                    (Amanda Reifer)
# 3    0.004219                                         (Arcangel)
# 4    0.008439                                    (Ariana Grande)
# 5    0.004219                                         (Aventura)
# 6    0.004219                                           (BLESSD)
# 7    0.008439                                        (Baby Keem)
# 8    0.168776                                        (Bad Bunny)
# 9    0.004219                                          (Becky G)
# 10   0.004219                                     (Beth Gibbons)
# 11   0.004219                                          (Beyonc�)
# 12   0.004219                                         (Bizarrap)
# 13   0.004219                                            (Blxst)
# 14   0.004219                                       (Buscabulla)
# 15   0.004219                                 (Chencho Corleone)
# 16   0.004219                                        (DJ Khaled)
# 17   0.008439                                     (Daddy Yankee)
# 18   0.004219                                        (Daft Punk)
# 19   0.004219                                     (De La Ghetto)
# 20   0.008439                                         (Doja Cat)
# 21   0.004219                                      (Don Toliver)
# 22   0.080169                                            (Drake)
# 23   0.004219                                       (Ed Sheeran)
# 24   0.004219                                   (Eladio Carrion)
# 25   0.004219                                   (Eslabon Armado)
# 26   0.088608                                             (Feid)
# 27   0.004219                                    (Fuerza Regida)
# 28   0.012658                                           (Future)
# 29   0.008439                               (Gabito Ballesteros)
# 30   0.008439                                    (Gesaffelstein)
# 31   0.004219                                 (Ghostface Killah)
# 32   0.004219                                         (Gorillaz)
# 33   0.008439                                   (Grupo Frontera)
# 34   0.004219                                            (Gunna)
# 35   0.071730                                     (Harry Styles)
# 36   0.004219                                        (Ice Spice)
# 37   0.008439                                         (J Balvin)
# 38   0.004219                                         (Jay Rock)
# 39   0.008439                                      (Jhay Cortez)
# 40   0.004219                                           (Jhayco)
# 41   0.004219                                  (Julieta Venegas)
# 42   0.012658                                         (Junior H)
# 43   0.097046                                   (Kendrick Lamar)
# 44   0.004219                                      (Kodak Black)
# 45   0.004219                                             (Kyla)
# 46   0.012658                                     (Lana Del Rey)
# 47   0.004219                                         (Lil Baby)
# 48   0.004219                                        (Lil Wayne)
# 49   0.004219                                 (Luis R Conriquez)
# 50   0.004219                                          (Madonna)
# 51   0.008439                                     (Metro Boomin)
# 52   0.012658                                             (Mora)
# 53   0.004219                                      (Myke Towers)
# 54   0.008439                                    (Natanael Cano)
# 55   0.004219                                       (Nengo Flow)
# 56   0.004219                                        (Nicky Jam)
# 57   0.004219                                       (Nio Garcia)
# 58   0.004219                                            (Ozuna)
# 59   0.004219                                          (Pailita)
# 60   0.004219                                      (Paloma Mami)
# 61   0.004219                                     (Paulo Londra)
# 62   0.067511                                       (Peso Pluma)
# 63   0.004219                                (Pharrell Williams)
# 64   0.004219                                  (Phoebe Bridgers)
# 65   0.004219                                    (Playboi Carti)
# 66   0.004219                                 (Polima WestCoast)
# 67   0.004219                                      (Post Malone)
# 68   0.004219                                      (Project Pat)
# 69   0.004219                                          (Quevedo)
# 70   0.004219                                           (ROSAL�)
# 71   0.004219                                   (Rauw Alejandro)
# 72   0.004219                                             (Robi)
# 73   0.004219                                      (Ryan Castro)
# 74   0.097046                                              (SZA)
# 75   0.004219                                            (Saiko)
# 76   0.004219                                          (Sam Dew)
# 77   0.004219                                           (Sampha)
# 78   0.004219                                        (Sean Paul)
# 79   0.008439                                             (Sech)
# 80   0.004219                                    (Sky Rompiendo)
# 81   0.004219                                              (Sog)
# 82   0.004219                                    (Summer Walker)
# 83   0.004219                              (Swedish House Mafia)
# 84   0.012658                                            (Tainy)
# 85   0.004219                                      (Tanna Leone)
# 86   0.160338                                     (Taylor Swift)
# 87   0.004219                                    (Taylour Paige)
# 88   0.004219                                             (Tems)
# 89   0.004219                                        (The Mar��)
# 90   0.156118                                       (The Weeknd)
# 91   0.004219                                        (Tony Dize)
# 92   0.016878                                     (Travis Scott)
# 93   0.008439                              (Tyler - The Creator)
# 94   0.004219                                           (WizKid)
# 95   0.008439                                           (Yandel)
# 96   0.004219                                        (Yng Lvcas)
# 97   0.004219                                       (Young Miko)
# 98   0.004219                                       (Young Thug)
# 99   0.042194                                 (21 Savage, Drake)
# 100  0.004219                                 (21 Savage, Gunna)
# 101  0.008439                          (21 Savage, Metro Boomin)
# 102  0.004219                     (21 Savage, Pharrell Williams)
# 103  0.004219                           (21 Savage, Project Pat)
# 104  0.004219                            (21 Savage, The Weeknd)
# 105  0.008439                          (21 Savage, Travis Scott)
# 106  0.004219                   (21 Savage, Tyler - The Creator)
# 107  0.004219                                      (Alejo, Feid)
# 108  0.004219                                      (Alejo, Robi)
# 227  0.004219                  (The Weeknd, Swedish House Mafia)
# 228  0.004219                  (The Weeknd, Tyler - The Creator)
# 229  0.004219                    (21 Savage, Drake, Project Pat)
# 230  0.004219                   (21 Savage, Travis Scott, Drake)
# 231  0.004219              (21 Savage, The Weeknd, Metro Boomin)
# 232  0.004219            (21 Savage, Metro Boomin, Travis Scott)
# 233  0.004219  (21 Savage, Tyler - The Creator, Pharrell Will...
# 234  0.004219                                (Alejo, Feid, Robi)
# 235  0.004219             (Amanda Reifer, Blxst, Kendrick Lamar)
# 236  0.004219               (Kendrick Lamar, Baby Keem, Sam Dew)
# 237  0.004219                  (Bad Bunny, Nio Garcia, J Balvin)
# 238  0.004219                (Julieta Venegas, Bad Bunny, Tainy)
# 239  0.004219                            (Bad Bunny, Sech, Mora)
# 240  0.004219                       (DJ Khaled, Lil Baby, Drake)
# 241  0.004219                      (Feid, De La Ghetto, Pailita)
# 242  0.004219                  (Feid, Paloma Mami, De La Ghetto)
# 243  0.004219             (Feid, Polima WestCoast, De La Ghetto)
# 244  0.004219               (Paloma Mami, De La Ghetto, Pailita)
# 245  0.004219          (Polima WestCoast, De La Ghetto, Pailita)
# 246  0.004219      (Paloma Mami, Polima WestCoast, De La Ghetto)
# 247  0.004219                              (Tems, Drake, Future)
# 248  0.004219                        (Future, Drake, Young Thug)
# 249  0.004219                              (Kyla, Drake, WizKid)
# 250  0.004219                               (Feid, Jhayco, Sech)
# 251  0.004219                              (Feid, Mora, Quevedo)
# 252  0.004219                                (Saiko, Feid, Mora)
# 253  0.004219                 (Feid, Sky Rompiendo, Myke Towers)
# 254  0.004219                       (Feid, Paloma Mami, Pailita)
# 255  0.004219                  (Feid, Polima WestCoast, Pailita)
# 256  0.004219              (Feid, Paloma Mami, Polima WestCoast)
# 257  0.004219                             (Saiko, Feid, Quevedo)
# 258  0.004219         (Gabito Ballesteros, Junior H, Peso Pluma)
# 259  0.004219    (Gabito Ballesteros, Peso Pluma, Natanael Cano)
# 260  0.004219  (Kendrick Lamar, Summer Walker, Ghostface Killah)
# 261  0.004219               (The Weeknd, Madonna, Playboi Carti)
# 262  0.004219                             (Saiko, Mora, Quevedo)
# 263  0.004219           (Paloma Mami, Polima WestCoast, Pailita)
# 264  0.004219                     (Ryan Castro, Sog, Peso Pluma)
# 265  0.004219         (Feid, Paloma Mami, De La Ghetto, Pailita)
# 266  0.004219    (Feid, Polima WestCoast, De La Ghetto, Pailita)
# 267  0.004219  (Feid, Paloma Mami, Polima WestCoast, De La Gh...
# 268  0.004219  (Paloma Mami, Polima WestCoast, De La Ghetto, ...
# 269  0.004219                       (Saiko, Feid, Mora, Quevedo)
# 270  0.004219     (Feid, Paloma Mami, Polima WestCoast, Pailita)
# 271  0.004219  (De La Ghetto, Paloma Mami, Polima WestCoast, ...

# %%
rules = association_rules(df=frequent_itemsets, metric="confidence", min_threshold=0.5, num_itemsets=1)

filtered_rules = rules[(rules['antecedents'].map(len) > 1) & 
                       (rules['consequents'].map(len) == 1)]

filtered_rules = filtered_rules.sort_values(by=['confidence', 'lift', 'leverage'], ascending=False, inplace=False)

filtered_rules
# Out:
#                                            antecedents            consequents  \
# 159                   (21 Savage, Tyler - The Creator)    (Pharrell Williams)
# 164                                      (Alejo, Feid)                 (Robi)
# 166                                       (Feid, Robi)                (Alejo)
# 170                    (Amanda Reifer, Kendrick Lamar)                (Blxst)
# 171                            (Kendrick Lamar, Blxst)        (Amanda Reifer)
# 192                                 (DJ Khaled, Drake)             (Lil Baby)
# 193                                  (Lil Baby, Drake)            (DJ Khaled)
# 196                               (Feid, De La Ghetto)              (Pailita)
# 197                                    (Feid, Pailita)         (De La Ghetto)
# 201                                (Feid, Paloma Mami)         (De La Ghetto)
# 202                               (Feid, De La Ghetto)          (Paloma Mami)
# 206                           (Feid, Polima WestCoast)         (De La Ghetto)
# 207                               (Feid, De La Ghetto)     (Polima WestCoast)
# 211                        (Paloma Mami, De La Ghetto)              (Pailita)
# 212                             (Paloma Mami, Pailita)         (De La Ghetto)
# 213                            (De La Ghetto, Pailita)          (Paloma Mami)
# 217                   (Polima WestCoast, De La Ghetto)              (Pailita)
# 218                        (Polima WestCoast, Pailita)         (De La Ghetto)
# 219                            (De La Ghetto, Pailita)     (Polima WestCoast)
# 223                    (Paloma Mami, Polima WestCoast)         (De La Ghetto)
# 224                        (Paloma Mami, De La Ghetto)     (Polima WestCoast)
# 225                   (Polima WestCoast, De La Ghetto)          (Paloma Mami)
# 237                                      (Kyla, Drake)               (WizKid)
# 239                                    (Drake, WizKid)                 (Kyla)
# 243                                       (Feid, Sech)               (Jhayco)
# 255                              (Feid, Sky Rompiendo)          (Myke Towers)
# 256                                (Feid, Myke Towers)        (Sky Rompiendo)
# 260                                (Feid, Paloma Mami)              (Pailita)
# 261                                    (Feid, Pailita)          (Paloma Mami)
# 265                           (Feid, Polima WestCoast)              (Pailita)
# 266                                    (Feid, Pailita)     (Polima WestCoast)
# 270                                (Feid, Paloma Mami)     (Polima WestCoast)
# 271                           (Feid, Polima WestCoast)          (Paloma Mami)
# 275                                      (Saiko, Feid)              (Quevedo)
# 277                                    (Feid, Quevedo)                (Saiko)
# 288                    (Kendrick Lamar, Summer Walker)     (Ghostface Killah)
# 289                 (Kendrick Lamar, Ghostface Killah)        (Summer Walker)
# 293                              (The Weeknd, Madonna)        (Playboi Carti)
# 294                        (The Weeknd, Playboi Carti)              (Madonna)
# 298                                      (Saiko, Mora)              (Quevedo)
# 300                                    (Mora, Quevedo)                (Saiko)
# 303                    (Paloma Mami, Polima WestCoast)              (Pailita)
# 304                             (Paloma Mami, Pailita)     (Polima WestCoast)
# 305                        (Polima WestCoast, Pailita)          (Paloma Mami)
# 310                          (Ryan Castro, Peso Pluma)                  (Sog)
# 311                                  (Sog, Peso Pluma)          (Ryan Castro)
# 314                  (Feid, Paloma Mami, De La Ghetto)              (Pailita)
# 315                       (Feid, Paloma Mami, Pailita)         (De La Ghetto)
# 316                      (Feid, De La Ghetto, Pailita)          (Paloma Mami)
# 327             (Feid, Polima WestCoast, De La Ghetto)              (Pailita)
# 169               1.0  0.003810         inf       0.906780  0.043478
# 176               1.0  0.003810         inf       0.906780  0.043478
# 290               1.0  0.003810         inf       0.906780  0.043478
# 295               1.0  0.003561         inf       0.847458  0.027027
# 181               1.0  0.003507         inf       0.834746  0.025000
# 185               1.0  0.003507         inf       0.834746  0.025000
# 189               1.0  0.003507         inf       0.834746  0.025000
# 174               1.0  0.004184    1.991561       1.000000  0.500000
# 180               1.0  0.004184    1.991561       1.000000  0.500000
# 231               1.0  0.004184    1.991561       1.000000  0.500000
# 233               1.0  0.004184    1.991561       1.000000  0.500000
# 247               1.0  0.004184    1.991561       1.000000  0.500000
# 253               1.0  0.004184    1.991561       1.000000  0.500000
# 156               1.0  0.004148    1.983122       0.991489  0.333333
# 283               1.0  0.004148    1.983122       0.991489  0.333333
# 285               1.0  0.004148    1.983122       0.991489  0.333333
# 281               1.0  0.004113    1.974684       0.982979  0.250000
# 155               1.0  0.004077    1.966245       0.974468  0.200000
# 150               1.0  0.003721    1.881857       0.889362  0.066667
# 149               1.0  0.003543    1.839662       0.846809  0.050000
# 152               1.0  0.002902    1.687764       0.693617  0.026316
#
#      certainty  kulczynski
# 159   1.000000    1.000000
# 164   1.000000    1.000000
# 166   1.000000    1.000000
# 170   1.000000    1.000000
# 171   1.000000    1.000000
# 192   1.000000    1.000000
# 193   1.000000    1.000000
# 196   1.000000    1.000000
# 197   1.000000    1.000000
# 201   1.000000    1.000000
# 202   1.000000    1.000000
# 206   1.000000    1.000000
# 207   1.000000    1.000000
# 211   1.000000    1.000000
# 212   1.000000    1.000000
# 213   1.000000    1.000000
# 217   1.000000    1.000000
# 218   1.000000    1.000000
# 219   1.000000    1.000000
# 223   1.000000    1.000000
# 224   1.000000    1.000000
# 225   1.000000    1.000000
# 237   1.000000    1.000000
# 239   1.000000    1.000000
# 243   1.000000    1.000000
# 255   1.000000    1.000000
# 256   1.000000    1.000000
# 260   1.000000    1.000000
# 261   1.000000    1.000000
# 265   1.000000    1.000000
# 266   1.000000    1.000000
# 270   1.000000    1.000000
# 271   1.000000    1.000000
# 275   1.000000    1.000000
# 277   1.000000    1.000000
# 288   1.000000    1.000000
# 289   1.000000    1.000000
# 293   1.000000    1.000000
# 294   1.000000    1.000000
# 298   1.000000    1.000000
# 300   1.000000    1.000000
# 303   1.000000    1.000000
# 304   1.000000    1.000000
# 305   1.000000    1.000000
# 310   1.000000    1.000000
# 311   1.000000    1.000000
# 314   1.000000    1.000000
# 315   1.000000    1.000000
# 316   1.000000    1.000000
# 327   1.000000    1.000000
# 328   1.000000    1.000000
# 329   1.000000    1.000000
# 340   1.000000    1.000000
# 341   1.000000    1.000000
# 342   1.000000    1.000000
# 353   1.000000    1.000000
# 354   1.000000    1.000000
# 355   1.000000    1.000000
# 356   1.000000    1.000000
# 367   1.000000    1.000000
# 370   1.000000    1.000000
# 379   1.000000    1.000000
# 380   1.000000    1.000000
# 381   1.000000    1.000000
# 392   1.000000    1.000000
# 394   1.000000    1.000000
# 395   1.000000    1.000000
# 396   1.000000    1.000000
# 151   1.000000    0.750000
# 160   1.000000    0.750000
# 175   1.000000    0.750000
# 179   1.000000    0.750000
# 188   1.000000    0.750000
# 242   1.000000    0.750000
# 184   1.000000    0.666667
# 187   1.000000    0.666667
# 229   1.000000    0.666667
# 235   1.000000    0.666667
# 248   1.000000    0.666667
# 251   1.000000    0.666667
# 299   1.000000    0.666667
# 368   1.000000    0.666667
# 147   1.000000    0.535714
# 153   1.000000    0.535714
# 157   1.000000    0.535714
# 161   1.000000    0.535714
# 280   1.000000    0.531250
# 284   1.000000    0.531250
# 309   1.000000    0.531250
# 146   1.000000    0.526316
# 191   1.000000    0.526316
# 230   1.000000    0.526316
# 234   1.000000    0.526316
# 238   1.000000    0.526316
# 165   1.000000    0.523810
# 198   1.000000    0.523810
# 203   1.000000    0.523810
# 208   1.000000    0.523810
# 244   1.000000    0.523810
# 249   1.000000    0.523810
# 252   1.000000    0.523810
# 257   1.000000    0.523810
# 262   1.000000    0.523810
# 267   1.000000    0.523810
# 272   1.000000    0.523810
# 276   1.000000    0.523810
# 317   1.000000    0.523810
# 330   1.000000    0.523810
# 343   1.000000    0.523810
# 369   1.000000    0.523810
# 382   1.000000    0.523810
# 393   1.000000    0.523810
# 169   1.000000    0.521739
# 176   1.000000    0.521739
# 290   1.000000    0.521739
# 295   1.000000    0.513514
# 181   1.000000    0.512500
# 185   1.000000    0.512500
# 189   1.000000    0.512500
# 174   0.497881    0.750000
# 180   0.497881    0.750000
# 231   0.497881    0.750000
# 233   0.497881    0.750000
# 247   0.497881    0.750000
# 253   0.497881    0.750000
# 156   0.495745    0.500000
# 283   0.495745    0.500000
# 285   0.495745    0.500000
# 281   0.493590    0.416667
# 155   0.491416    0.375000
# 150   0.468610    0.285714
# 149   0.456422    0.276316
# 152   0.407500    0.263514

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('spotify-2023.csv')

# Select features for clustering
features = ['bpm', 'danceability_%', 'energy_%', 'valence_%', 
            'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
features = ['']

# Drop missing values for the selected features
data = data.dropna(subset=features)

# Normalize the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(data[features])

# Determine optimal number of clusters using the Elbow Method
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features_scaled)
    inertia.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.show()

# Apply K-Means with the optimal number of clusters
optimal_k = 4  # Adjust based on the Elbow Curve
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
data['Cluster'] = kmeans.fit_predict(features_scaled)

# Reduce dimensions to 2 for visualization
pca = PCA(n_components=2)
reduced_features = pca.fit_transform(features_scaled)
data['PCA1'] = reduced_features[:, 0]
data['PCA2'] = reduced_features[:, 1]

# Plot the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='PCA1', y='PCA2', hue='Cluster', palette='viridis', s=100)
plt.title('Clusters of Songs (Reduced to 2D)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()

# Display cluster feature summary
cluster_summary = data.groupby('Cluster')[features].mean()
print(cluster_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2963116/401908286.py in ?()
#      14             'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
#      15 features = ['']
#      16
#      17 # Drop missing values for the selected features
# ---> 18 data = data.dropna(subset=features)
#      19
#      20 # Normalize the features
#      21 scaler = StandardScaler()
#
# ~/Documents/educational/applied-ai/final-project/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['']

# %%
# Correlation Matrix ( Numeric Only )
corr_matrix = data.corr(numeric_only=True)

# Create a heatmap
plt.figure(figsize=np.array((10, 8)) * 3)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
(corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False).head(20))
# Out:
# in_spotify_playlists  in_apple_playlists    0.708277
# in_spotify_charts     in_deezer_charts      0.600205
#                       in_apple_charts       0.552232
# in_apple_playlists    in_apple_charts       0.414523
# danceability_%        valence_%             0.408451
# in_apple_charts       in_deezer_charts      0.383668
# in_apple_playlists    in_deezer_charts      0.369032
# valence_%             energy_%              0.357612
# in_spotify_playlists  in_apple_charts       0.271317
# in_spotify_charts     in_apple_playlists    0.233354
# artist_count          danceability_%        0.207027
# danceability_%        energy_%              0.198095
# released_year         danceability_%        0.187333
# danceability_%        speechiness_%         0.184977
# released_year         released_day          0.174282
# in_spotify_playlists  in_spotify_charts     0.164331
#                       in_deezer_charts      0.144342
# artist_count          energy_%              0.137096
# released_year         speechiness_%         0.133819
# artist_count          valence_%             0.127960
# dtype: float64

# %%
(corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False).tail(10))
# Out:
# in_apple_playlists  speechiness_%          -0.108011
# released_month      valence_%              -0.118571
# released_year       acousticness_%         -0.124156
# valence_%           instrumentalness_%     -0.132890
# bpm                 danceability_%         -0.147095
# in_apple_charts     speechiness_%          -0.151539
# released_year       in_apple_playlists     -0.198998
# danceability_%      acousticness_%         -0.236165
# released_year       in_spotify_playlists   -0.392204
# energy_%            acousticness_%         -0.577344
# dtype: float64

# %%
# Compute the correlation matrix
corr_matrix = data.corr(numeric_only=True)

# Extract the upper triangle of the correlation matrix
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Unstack the matrix to convert it into a series and drop NaN values
sorted_pairs = upper_triangle.unstack().dropna().sort_values(ascending=False).head(10)
inv_sorted_pairs = upper_triangle.unstack().dropna().sort_values(ascending=False).tail(10)

top_pairs = [pair for pair in sorted_pairs.index]
inv_top_pairs = [pair for pair in inv_sorted_pairs.index]

to_analyze = []
to_analyze.extend(sorted_pairs.index)
to_analyze.extend(inv_sorted_pairs.index)

to_analyze
# Out:
# [('streams (int)', 'in_spotify_playlists'),
#  ('streams (int)', 'in_apple_playlists'),
#  ('in_apple_playlists', 'in_spotify_playlists'),
#  ('in_deezer_charts', 'in_spotify_charts'),
#  ('in_apple_charts', 'in_spotify_charts'),
#  ('in_apple_charts', 'in_apple_playlists'),
#  ('valence_%', 'danceability_%'),
#  ('in_deezer_charts', 'in_apple_charts'),
#  ('in_deezer_charts', 'in_apple_playlists'),
#  ('energy_%', 'valence_%'),
#  ('acousticness_%', 'released_year'),
#  ('instrumentalness_%', 'valence_%'),
#  ('streams (int)', 'artist_count'),
#  ('danceability_%', 'bpm'),
#  ('speechiness_%', 'in_apple_charts'),
#  ('in_apple_playlists', 'released_year'),
#  ('streams (int)', 'released_year'),
#  ('acousticness_%', 'danceability_%'),
#  ('in_spotify_playlists', 'released_year'),
#  ('acousticness_%', 'energy_%')]

# %%
for (var2, var1) in inv_top_pairs:
    plt.gcf().set_facecolor('white')  # Figure background color
    plt.gca().set_facecolor('#FAFAFA')  # Axes background color
    plt.scatter(data[var2], data[var1], color = "magenta")
    plt.xlabel(var2)
    plt.ylabel(var1)
    # plt.title('Simple Scatterplot')
    plt.show()

    
    sns.set_style('white')
    plt.figure(figsize=(8, 6))
    sns.lmplot(data=data, x=var1, y=var2, height=6, aspect=1.2,scatter_kws={'color': 'magenta'}, 
               line_kws={'color': 'black'})
    plt.title(f'Scatter Plot of {var1} vs {var2}')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.show()
    #plt.savefig(f'images/lmplot_{var1}_{var2}.png', bbox_inches='tight')

# %%
# Perform regression analysis on the best pairs

for (var1, var2) in to_analyze:
    X = data[[var1]]
    y = data[var2]
    X = sm.add_constant(X)  # Adds a constant term to the predictor
    model = sm.OLS(y, X).fit()
    # print(f"Regression analysis for {var1} and {var2}:")
    # print(model.summary())
    # print()

    # Plot the regression line and data points
    plt.figure(figsize=(10, 6))
    plt.scatter(data[var1], data[var2], label='Data Points')
    plt.plot(data[var1], model.predict(X), color='red', label='Regression Line')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.title(f'Regression Analysis: {var1} vs {var2}')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Perform regression analysis on the best pairs
# ----> 3 for (var1, var2) in to_analyze:
#       4     X = data[[var1]]
#       5     y = data[var2]
#
# NameError: name 'to_analyze' is not defined

# %%
# Perform regression analysis on the best pairs

for (var2, var1) in to_analyze:
    X = data[[var1]]
    y = data[var2]
    X = sm.add_constant(X)  # Adds a constant term to the predictor
    model = sm.OLS(y, X).fit()
    # print(f"Regression analysis for {var1} and {var2}:")
    # print(model.summary())
    # print()

    # Plot the regression line and data points
    plt.figure(figsize=(10, 6))
    plt.scatter(data[var1], data[var2], label='Data Points')
    plt.plot(data[var1], model.predict(X), color='red', label='Regression Line')
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.title(f'Regression Analysis: {var1} vs {var2}')
    plt.legend()
    plt.show()
